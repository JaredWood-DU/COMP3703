# %% [markdown]
# ## Introduction
#
# Payment fraud detection is critical for banks, businesses, and consumers. In Europe alone, fraudulent transactions were estimated at €1.89 billion in 2019Links to an external site.. Worldwide, approximately 3.6%Links to an external site. of commerce revenue is lost to fraud. In this notebook, we train and evaluate a model to detect fraudulent transactions using the synthetic dataset attached to the book Reproducible Machine Learning for Credit Card Fraud DetectionLinks to an external site. by Le Borgne et al.
#
# Fraudulent transactions often cannot be detected by looking at transactions in isolation. Instead, fraudulent transactions are detected by looking at patterns across multiple transactions from the same user, to the same merchant, or with other types of relationships. To express these relationships in a way that is understandable by a machine learning model, and to augment features with feature engineering, we We use the TemporianLinks to an external site. preprocessing library.
#
# We preprocess a transaction dataset into a tabular dataset and use a feed-forward neural network to learn the patterns of fraud and make predictions.

# %% [markdown]
# ## Loading the Dataset

# %% [markdown]
# ## Preparing the Training Data

# %% [markdown]
# ## Split Dataset Into A Train, Validate, and Test Set

# %% [markdown]
# ## Train the Model

# %% [markdown]
# <h2> Conclusion/Deliverable </h2>
#
# <h5><ul>
# - What could be done to further improve the model's performance?
#     -
# - How computationally expensive was running this model? (What was the GPU/CPU usage?)
#     -
#     - Would this be expensive or cheap to run for a large dataset?
#         -
# </ul></h5>
